# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('tested.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.rename(columns={'Embarked':'from'}, inplace =True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.sample(6)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 306         1198         0       1  Allison, Mr. Hudson Joshua Creighton
# 394         1286         0       3              Kink-Heilmann, Mr. Anton
# 206         1098         1       3              McGowan, Miss. Katherine
# 238         1130         1       2                 Hiltunen, Miss. Marta
# 278         1170         0       2                  Ware, Mr. John James
# 265         1157         0       3                 Lyntakoff, Mr. Stanko
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin from
# 306    male  30.0      1      2    113781  151.5500  C22 C26    S
# 394    male  29.0      3      1    315153   22.0250      NaN    S
# 206  female  35.0      0      0      9232    7.7500      NaN    Q
# 238  female  18.0      1      1    250650   13.0000      NaN    S
# 278    male  30.0      1      0  CA 31352   21.0000      NaN    S
# ...

# %%
df.drop(columns=['PassengerId'], inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
# ...

# %%
fromt = df.pivot_table(index='from', values='Survived', columns='Pclass', aggfunc='sum')

# %%
fromt
# Out:
# Pclass   1   2   3
# from
# C       28   4   8
# Q        1   0  23
# S       21  26  41

# %%
sns.heatmap(fromt)
# Out:
# <Axes: xlabel='Pclass', ylabel='from'>

# %%
sns.kdeplot(df[df['Survived'] == 1]['Age'], label='Survived')
sns.kdeplot(df[df['Survived'] == 0]['Age'], label='NotSurvived')
plt.legend()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
age = df.pivot_table(index='Survived', values='Age', columns='Pclass', aggfunc='max')

# %%
age
# Out:
# Pclass       1     2     3
# Survived
# 0         67.0  63.0  60.5
# 1         76.0  60.0  47.0

# %%
sns.pairplot(df,hue = 'from')
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.pairplot(df,hue = 'Survived')
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean     0.363636    2.265550   30.272590    0.447368    0.392344   35.627188
# std      0.481622    0.841838   14.181209    0.896760    0.981429   55.907576
# min      0.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   39.000000    1.000000    0.000000   31.500000
# max      1.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
sns.barplot(x = 'Sex', y = 'Fare', data = df)
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %%
df['Cabin'].sample(60)
# Out:
# 195        NaN
# 149        NaN
# 295        NaN
# 269        NaN
# 205        NaN
# 270         C6
# 382        NaN
# 208        A11
# 189        NaN
# 265        NaN
# 43         NaN
# 180        NaN
# 88         NaN
# 19         NaN
# 137        NaN
# 325        NaN
# 290        NaN
# 27         NaN
# 115        NaN
# 275        NaN
# 151        NaN
# 380        NaN
# 206        NaN
# 109          F
# 121        NaN
# 211        NaN
# 156        C97
# 259        NaN
# 119        NaN
# 328        NaN
# 359        NaN
# 20         NaN
# 257        NaN
# 251        NaN
# 126        NaN
# 307        NaN
# 401        NaN
# 26         B36
# 200        NaN
# 207        NaN
# 185        NaN
# 214        NaN
# 408        NaN
# 138        NaN
# 237        NaN
# 286        NaN
# 38         NaN
# 249        NaN
# 209        NaN
# 222        F33
# 227        NaN
# 128        NaN
# 175        NaN
# 55         NaN
# 365        NaN
# 81     C55 C57
# 114    C55 C57
# 413        NaN
# ...

# %%
df[df['Cabin']== 'C130']
# Out:
#     Survived  Pclass                  Name     Sex   Age  SibSp  Parch  \
# 74         1       1  Geiger, Miss. Amalie  female  35.0      0      0
#
#     Ticket   Fare Cabin from
# 74  113503  211.5  C130    C

# %%
# we cannot do it like this as it is nominal data -> ONE HOT ENCODING is needed to convert this data to numerical data
# places = []
# for i in df['from']:
#     if i == 'C':
#         places.append(1)
#     elif i == 'Q':
#         places.append(0)
#     else:
#         places.append(2)

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %%
# same for this it is ominal data one hot encoding is needed to do it
# sex = [];
# for i in df['Sex']:
#     if i == 'male':
#         sex.append(1)
#     else:
#         sex.append(0)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
# ...

# %%
sns.barplot(x = 'from', y ='Survived', data = df)
# Out:
# <Axes: xlabel='from', ylabel='Survived'>

# %%
df['Family'] = df['Parch']+df['SibSp']

# %%
df.drop(columns =['Ticket', 'Cabin', 'Parch', 'SibSp', 'Name'], inplace = True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age      Fare from  Family
# 0           0       3    male  34.5    7.8292    Q       0
# 1           1       3  female  47.0    7.0000    S       1
# 2           0       2    male  62.0    9.6875    Q       0
# 3           0       3    male  27.0    8.6625    S       0
# 4           1       3  female  22.0   12.2875    S       2
# ..        ...     ...     ...   ...       ...  ...     ...
# 413         0       3    male   NaN    8.0500    S       0
# 414         1       1  female  39.0  108.9000    C       0
# 415         0       3    male  38.5    7.2500    S       0
# 416         0       3    male   NaN    8.0500    S       0
# 417         0       3    male   NaN   22.3583    C       2
#
# [418 rows x 7 columns]

# %%
df['Survived'].corr(df['Family'])
# Out:
# 0.1618028934862859

# %%
me = df['Age'].mean()

# %%
df['Age'] = df['Age'].fillna(me)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#      Survived  Pclass     Sex       Age      Fare from  Family
# 0           0       3    male  34.50000    7.8292    Q       0
# 1           1       3  female  47.00000    7.0000    S       1
# 2           0       2    male  62.00000    9.6875    Q       0
# 3           0       3    male  27.00000    8.6625    S       0
# 4           1       3  female  22.00000   12.2875    S       2
# ..        ...     ...     ...       ...       ...  ...     ...
# 413         0       3    male  30.27259    8.0500    S       0
# 414         1       1  female  39.00000  108.9000    C       0
# 415         0       3    male  38.50000    7.2500    S       0
# 416         0       3    male  30.27259    8.0500    S       0
# 417         0       3    male  30.27259   22.3583    C       2
#
# [418 rows x 7 columns]

# %%
get = df.groupby(['Survived', 'from', 'Sex'])
get = get.size

# %%
get
# Out:
# <bound method GroupBy.size of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000206867CD410>>
